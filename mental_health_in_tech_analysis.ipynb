# %% [markdown]
# # Mental Health in Tech Industry

# %% [markdown]
# ## Introduction

# %% [markdown]
# In recent years, mental health has become an increasingly important topic in the workplace, particularly in the tech industry. High stress levels, long working hours, and a fast-paced environment can significantly impact the mental well-being of employees. This project aims to analyze mental health trends within the tech industry and develop a predictive model to identify factors contributing to mental health issues among employees.

# %%
import pandas as pd
import sqlite3

# %%
df = pd.read_csv('survey.csv')
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
# Create a SQLite connection
conn = sqlite3.connect('mental_health.db')

df.to_sql('mental_health_survey', conn, if_exists='replace', index=False)
# Out:
# 1259

# %%
# Function to run SQL queries
def run_query(query):
    return pd.read_sql_query(query, conn)

# Overview of dataset
query = "SELECT * FROM mental_health_survey LIMIT 10;"
run_query(query)
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL          None
# 1  2014-08-27 11:29:37   44       M   United States    IN          None
# 2  2014-08-27 11:29:44   32    Male          Canada  None          None
# 3  2014-08-27 11:29:46   31    Male  United Kingdom  None          None
# 4  2014-08-27 11:30:22   31    Male   United States    TX          None
# 5  2014-08-27 11:31:22   33    Male   United States    TN          None
# 6  2014-08-27 11:31:50   35  Female   United States    MI          None
# 7  2014-08-27 11:32:05   39       M          Canada  None          None
# 8  2014-08-27 11:32:39   42  Female   United States    IL          None
# 9  2014-08-27 11:32:43   23    Male          Canada  None          None
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# ...

# %% [markdown]
# ## Prevalence of Mental Health Issues

# %%
query = """
SELECT COUNT(*) AS total_respondents,
       SUM(CASE WHEN Treatment = 'Yes' THEN 1 ELSE 0 END) AS mental_health_issues
FROM mental_health_survey;
"""
run_query(query)
# Out:
#    total_respondents  mental_health_issues
# 0               1259                   637

# %% [markdown]
# ## Mental Health Issues by Gender

# %%
query = """
SELECT Gender,
       COUNT(*) AS total,
       SUM(CASE WHEN Treatment = 'Yes' THEN 1 ELSE 0 END) AS mental_health_issues
FROM mental_health_survey
GROUP BY Gender;
"""
run_query(query)
# Out:
#                                             Gender  total  \
# 0                               A little about you      1
# 1                                          Agender      1
# 2                                              All      1
# 3                                        Androgyne      1
# 4                                       Cis Female      1
# 5                                         Cis Male      2
# 6                                          Cis Man      1
# 7                                             Enby      1
# 8                                                F     38
# 9                                           Femake      1
# 10                                          Female    121
# 11                                         Female       2
# 12                                    Female (cis)      1
# 13                                  Female (trans)      2
# 14                                     Genderqueer      1
# ...

# %% [markdown]
# ## Impact of Work Environment

# %%
query = """
SELECT Work_interfere,
       COUNT(*) AS total,
       SUM(CASE WHEN Treatment = 'Yes' THEN 1 ELSE 0 END) AS mental_health_issues
FROM mental_health_survey
GROUP BY Work_interfere;
"""
run_query(query)
# Out:
#   work_interfere  total  mental_health_issues
# 0           None    264                     4
# 1          Never    213                    30
# 2          Often    144                   123
# 3         Rarely    173                   122
# 4      Sometimes    465                   358

# %% [markdown]
# ## Significant Predictors of Mental Health Issues

# %%
query = """
SELECT AVG(CASE WHEN Treatment = 'Yes' THEN Age ELSE NULL END) AS avg_age_mental_health_issues,
       AVG(CASE WHEN Treatment = 'No' THEN Age ELSE NULL END) AS avg_age_no_mental_health_issues
FROM mental_health_survey;
"""
run_query(query)
# Out:
#    avg_age_mental_health_issues  avg_age_no_mental_health_issues
# 0                  1.569859e+08                        31.361736

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Conducted a thorough EDA to understand the data better.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of Age
plt.figure(figsize=(10,6))
sns.histplot(df['Age'], kde=True, bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Mental Health Issues by Gender
plt.figure(figsize=(10,6))
sns.countplot(x='Gender', hue='treatment', data=df)
plt.title('Mental Health Issues by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# Work Interference vs. Treatment
plt.figure(figsize=(10,6))
sns.countplot(x='work_interfere', hue='treatment', data=df)
plt.title('Work Interference vs. Mental Health Treatment')
plt.xlabel('Work Interference')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# Investigating correlations between different factors to identify significant predictors of mental health issues.

# %%
# Convert categorical variables to numerical for correlation analysis
df_encoded = df.copy()
df_encoded['treatment'] = df_encoded['treatment'].apply(lambda x: 1 if x == 'Yes' else 0)
df_encoded['family_history'] = df_encoded['family_history'].apply(lambda x: 1 if x == 'Yes' else 0)

# Drop non-numerical columns before calculating correlation
df_encoded_numeric = df_encoded.select_dtypes(include=['number'])

# Correlation matrix
corr_matrix = df_encoded_numeric.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Predictive Modeling

# %% [markdown]
# Built a predictive model to forecast which employees are at risk of mental health issues.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# Prepare the data
X = df_encoded.drop(columns=['treatment', 'Timestamp'])

# Identify categorical and numerical columns
categorical_features = ['Gender', 'Country', 'self_employed', 'tech_company', 'wellness_program', 'seek_help', 'anonymity', 'leave', 'mental_health_consequence', 'phys_health_consequence', 'coworkers', 'supervisor', 'mental_health_interview', 'phys_health_interview', 'mental_vs_physical', 'obs_consequence']
numerical_features = X.select_dtypes(include=['number']).columns.tolist()

# Create transformers for categorical and numerical features
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
numerical_transformer = 'passthrough'  # No transformation for numerical features

# Preprocessor to apply transformations
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Apply transformations to X
X_transformed = preprocessor.fit_transform(X)

y = df_encoded['treatment']

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.3, random_state=42)

# Train the model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[116  65]
#  [ 64 133]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       181
#            1       0.67      0.68      0.67       197
#
#     accuracy                           0.66       378
#    macro avg       0.66      0.66      0.66       378
# weighted avg       0.66      0.66      0.66       378

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# Optimizing the Random Forest Model's hyperparameters using techniques such as Grid Search.

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 200],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth': [4, 6, 8, 10],
    'criterion': ['gini', 'entropy']
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# Analyzing feature importance to understand which features contribute the most to the predictions.

# %%
feature_importances = model.feature_importances_
feature_names = numerical_features + list(preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features))

feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importances})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

plt.figure(figsize=(12,8))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.show()

# %% [markdown]
# ## Cross-Validation

# %% [markdown]
# Used cross-validation to ensure the model's performance is consistent across different subsets of the data.

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(model, X_transformed, y, cv=5)
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", cv_scores.mean())
# Out:
# Cross-Validation Scores: [0.71031746 0.67460317 0.6468254  0.67857143 0.60159363]
# Mean CV Score: 0.6623822171630936

# %% [markdown]
# ## Additional Visualizations

# %% [markdown]
# Visualized the ROC curve and calculated the AUC to evaluate the model's performance.

# %%
from sklearn.metrics import roc_curve, roc_auc_score

y_prob = model.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
auc = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc:.2f}')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# ## Model Comparison

# %% [markdown]
# Compared the performance of different models such as Logistic Regression, SVM, or Gradient Boosting.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier

models = {
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(),
    'SVM': SVC(probability=True),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"{name} Classification Report:")
    print(classification_report(y_test, y_pred))
    print()
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64       181
#            1       0.67      0.68      0.67       197
#
#     accuracy                           0.66       378
#    macro avg       0.66      0.66      0.66       378
# weighted avg       0.66      0.66      0.66       378
#
#
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68       181
#            1       0.71      0.69      0.70       197
#
#     accuracy                           0.69       378
#    macro avg       0.69      0.69      0.69       378
# weighted avg       0.69      0.69      0.69       378
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Key Findings
#
# 1. **Prevalence of Mental Health Issues**:
#    - The analysis revealed a significant prevalence of mental health issues among employees in the tech industry. A substantial portion of respondents reported experiencing mental health conditions and seeking treatment.
#
# 2. **Factors Influencing Mental Health**:
#    - Several factors were identified as significant predictors of mental health issues, including work interference, family history of mental illness, availability of mental health benefits, and the level of comfort in discussing mental health issues with coworkers and supervisors.
#    - Gender and age also played crucial roles, with certain demographics showing higher vulnerability to mental health conditions.
#
# 3. **Model Performance**:
#    - The predictive model developed using a Random Forest classifier achieved satisfactory performance, with a good balance between precision and recall. The model effectively identified individuals at risk of mental health issues based on various features.
#    - Feature importance analysis highlighted key factors contributing to the prediction, such as work interference, family history, and availability of wellness programs.

# %% [markdown]
# ### Recommendations
#
# Based on the findings from the analysis and predictive modeling, the following recommendations are proposed to improve mental health support in the tech industry:
#
# 1. **Promote Mental Health Awareness**:
#    - Increase awareness about mental health issues and reduce stigma through regular workshops, seminars, and training sessions.
#    - Encourage open discussions about mental health to create a supportive work environment.
#
# 2. **Enhance Mental Health Benefits**:
#    - Provide comprehensive mental health benefits, including access to counseling services, therapy sessions, and wellness programs.
#    - Ensure that employees are aware of the available resources and how to access them.
#
# 3. **Improve Work-Life Balance**:
#    - Implement policies that promote a healthy work-life balance, such as flexible working hours, remote work options, and regular breaks.
#    - Monitor workload and prevent burnout by setting realistic expectations and providing support where needed.
#
# 4. **Create a Supportive Work Environment**:
#    - Foster a culture of empathy and support by training managers and supervisors to recognize signs of mental distress and provide appropriate assistance.
#    - Encourage employees to seek help without fear of negative consequences by ensuring confidentiality and anonymity in mental health support services.
#
# 5. **Regular Monitoring and Feedback**:
#    - Conduct regular surveys and assessments to monitor the mental health status of employees and gather feedback on existing support programs.
#    - Use the insights gained to continuously improve mental health initiatives and address emerging issues promptly.

# %% [markdown]
# ### Final Thoughts
#
# The importance of mental health in the workplace cannot be overstated. This project has provided valuable insights into the factors affecting mental health in the tech industry and demonstrated the potential of predictive modeling in identifying at-risk individuals. By implementing the recommended strategies, companies can make significant strides in supporting their employees' mental health and fostering a positive and productive work environment.
